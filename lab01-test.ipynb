# %% [markdown]
# # Lab 01 Test
# ## 2/5/26
#
# This is my in-class stuff from 2/5/26.

# %% [markdown]
# ## Part 3

# %%
formula_string = 'Capital Asset Pricing Model'

# %%
type(formula_string)
# Out:
# str

# %% [markdown]
# ## Part 4

# %%
pv = 100/(1+0.05)**2
pv
# Out:
# 90.70294784580499

# %%
print(pv)
# Out:
# 90.70294784580499

# %% [markdown]
# ## Part 5

# %%
stock = ['Apple Inc.', 'AAPL', 172.39]

# %%
stock[1]
# Out:
# 'AAPL'

# %% [markdown]
# ## Part 8

# %%
import numpy as np
